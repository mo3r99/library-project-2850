// %%
%useLatestDescriptors
%use dataframe

val df = DataFrame.readCsv("/Users/muhammadrauf/Documents/Dev Projects/library-project-2850/server/src/main/resources/booklist.csv")

// %%
df.generateInterfaces()
// Out:
// @DataSchema
// interface _DataFrameType {
//     val author: String
//     @ColumnName("format_code")
//     val formatCode: String
//     @ColumnName("isbn_13")
//     val isbn13: Double?
//     @ColumnName("location_code")
//     val locationCode: String?
//     val notes: String?
//     val title: String
// }
